# %% [markdown]
# This Jupyter Notebook can be used for easy exploration of MariaDB database schema and testing queries interactively. In order to use, make sure to:
#
# Setting up a local database:
# 1. Install MariaDB 10.5.13-MariaDB from https://mariadb.org/download/?t=mariadb&o=true&p=mariadb&r=10.5.13&os=windows&cpu=x86_64&pkg=msi
# 2. Open MariaDB's command line interface in your terminal (e.g. "C:\ProgramData\Microsoft\Windows\Start Menu\Programs\MariaDB 10.5 (x64)\MySQL Client (MariaDB 10.5 (x64)).lnk")
# 3. Create and select a new local database:
#     `CREATE DATABASE sodis_app_v1`
#     `USE DATABASE sodis_app_v1`
# 4. Ingest data from sql-dump by just copy/pasting the entire content of "sodis_dbv1_dump.sql" into the console application.
#
#
# Setting up Python:
# 1. Install Python (e.g. version 3.7.9)
# 2. Create a virtual environment
#     `"python -m venv .venv" and activate it ".venv/Scripts/activate"`
# 3. Install dependencies
#     `"pip install -r requirements.txt"`
# 4. Make sure to update any environment variables within your local .env file, pointing to your MariaDB database server.
# 5. Run this notebook

# %%
import dotenv
import os
import pandas
import sqlalchemy
import pathlib

# %load_ext autoreload
# %autoreload 2

dotenv.load_dotenv()
exports_dir = pathlib.Path("exports")
exports_dir.mkdir(exist_ok=True)

print(f"""
    Database server at: '{os.getenv('MARIADB_HOST')}'. 
    Database name is: '{os.getenv('MARIADB_DBNAME')}'.
    """)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#
#     Database server at: 'localhost'.
#     Database name is: 'sodis_app_v1'.

# %%
engine = sqlalchemy.create_engine(f"mysql+pymysql://{os.getenv('MARIADB_USER')}:{os.getenv('MARIADB_KEY')}@{os.getenv('MARIADB_HOST')}/{os.getenv('MARIADB_DBNAME')}")
conn = engine.connect()
tables = pandas.read_sql("SHOW TABLES;", engine)
tables
# Out:
#    Tables_in_sodis_app_v1
# 0                  answer
# 1        completed_survey
# 2              input_type
# 3             interviewee
# 4           option_choice
# 5                 project
# 6                question
# 7          question_image
# 8         question_option
# 9                    stat
# 10          survey_header
# 11         survey_section
# 12                   user
# 13                village

# %%
DENORMALIZE_QUERY = """
    SELECT 
        *
    FROM answer
    LEFT JOIN completed_survey
        ON completed_survey.id=answer.completed_survey_id
    LEFT JOIN user
        ON completed_survey.user_id=user.id
    LEFT JOIN interviewee 
        ON interviewee.id=completed_survey.interviewee_id
    LEFT JOIN survey_header
        ON survey_header.id=completed_survey.survey_header_id
    LEFT JOIN project
        ON project.id=survey_header.project_id
    LEFT JOIN village
        ON village.id=village_id
    LEFT JOIN survey_section
        ON survey_header.id=survey_section.survey_header_id
    LEFT JOIN question
        ON question.id=answer.question_id
    LEFT JOIN question_image
        ON question_image.id=question.question_images_id
    LEFT JOIN input_type
        ON input_type.id=question.input_type_id
    LEFT JOIN question_option
        ON answer.question_option_id=question_option.id
        ;
"""

denormalized_database = pandas.read_sql(DENORMALIZE_QUERY, engine)
print(denormalized_database.columns)
denormalized_database.head()
# Out:
# Index(['id', 'question_option_id', 'answer_text', 'completed_survey_id',
#        'image_url', 'question_id', 'id', 'interviewee_id', 'survey_header_id',
#        'creation_date', 'user_id', 'longitude', 'latitude', 'id', 'first_name',
#        'last_name', 'firebase_id', 'email', 'type', 'id', 'name', 'village_id',
#        'user_id', 'image_url', 'id', 'survey_name', 'project_id', 'id', 'name',
#        'id', 'name', 'id', 'survey_header_id', 'section_name', 'id',
#        'survey_section_id', 'input_type_id', 'question_name',
#        'dependent_question_id', 'dependent_question_option_id',
#        'question_images_id', 'id', 'url', 'id', 'input_type_name', 'id',
#        'question_id', 'option_choice_id'],
#       dtype='object')
#                                      id  question_option_id answer_text  \
# 0  02ed3eac-ea95-449d-bdb7-871bdb844529             10146.0        None
# 1  09d8a16d-a026-4b68-9ff1-d70da21bd4de             10126.0        None
# 2  07d4e063-6283-4381-8486-8db13a35543c             10225.0        None
# 3  0a11cf06-6469-4ca8-908d-b68064d7c0dd              9900.0        None
# 4  0ef9d0ca-f3f0-4994-a416-b635e163f2db              9888.0        None
#
#                     completed_survey_id image_url  question_id  \
# 0  0011ccd6-15b5-47e5-80bc-5d527347518a      None         3896
# 1  0011ccd6-15b5-47e5-80bc-5d527347518a      None         3891
# 2  013524b4-9149-4544-8b44-5e5270e9d8c1      None         3926
# 3  01817771-1a67-4d47-be0d-0ceec54f9bc7      None         3805
# 4  01817771-1a67-4d47-be0d-0ceec54f9bc7      None         3801
#
#                                      id                        interviewee_id  \
# 0  0011ccd6-15b5-47e5-80bc-5d527347518a  079397b5-9f2e-4490-9ebf-795ff2c8c679
# 1  0011ccd6-15b5-47e5-80bc-5d527347518a  079397b5-9f2e-4490-9ebf-795ff2c8c679
# 2  013524b4-9149-4544-8b44-5e5270e9d8c1  d3abcc2e-555e-4570-aa93-2420dd2262c5
# 3  01817771-1a67-4d47-be0d-0ceec54f9bc7  5619548e-2457-4b46-b69c-b298aa6708f6
# 4  01817771-1a67-4d47-be0d-0ceec54f9bc7  5619548e-2457-4b46-b69c-b298aa6708f6
#
#    survey_header_id            creation_date  ...  dependent_question_id  \
# 0             515.0  2021-10-27 15:47:26.292  ...                    NaN
# 1             515.0  2021-10-27 15:47:26.292  ...                    NaN
# 2             518.0  2021-08-22 06:25:33.687  ...                    NaN
# 3             508.0    2021-08-24 12:28:03.0  ...                 3792.0
# 4             508.0    2021-08-24 12:28:03.0  ...                 3792.0
#
#    dependent_question_option_id  question_images_id      id  \
# 0                           NaN              1183.0  1183.0
# 1                           NaN              1178.0  1178.0
# 2                           NaN              1201.0  1201.0
# 3                        9868.0              1116.0  1116.0
# 4                        9868.0              1112.0  1112.0
#
#                                                  url id input_type_name  \
# 0  https://firebasestorage.googleapis.com/v0/b/ak...  1   single choice
# 1  https://firebasestorage.googleapis.com/v0/b/ak...  1   single choice
# 2  https://firebasestorage.googleapis.com/v0/b/ak...  1   single choice
# 3  https://firebasestorage.googleapis.com/v0/b/ak...  1   single choice
# 4  https://firebasestorage.googleapis.com/v0/b/ak...  1   single choice
#
#         id  question_id option_choice_id
# 0  10146.0       3896.0           1267.0
# 1  10126.0       3891.0           1267.0
# 2  10225.0       3926.0           1272.0
# 3   9900.0       3805.0           1235.0
# 4   9888.0       3801.0           1240.0
#
# [5 rows x 48 columns]

# %%
denormalized_database.to_excel("exports/denormalized_sodis_sqldb.xlsx")

# %% [markdown]
# ## List of appliedInterventions
#
# multiple surveys linked to one intervention better solved in application code:
#
# (1) query all applied interventions,
#
# (2) when creating objects to be written to Amplify, link array of survey objects based on results of query in subsequent cell (surveys_for_intervention_id)

# %%
applied_interventions = pandas.read_sql(""" 
    SELECT 
        completed_survey.id AS executed_survey_id,
        project.name as intervention_name, 
        project.id as intervention_id,
        interviewee.id AS interviewee_id, 
        interviewee.name AS interviewee_name,
        user.id AS whoDidIt_id,
        user.first_name AS whoDidIt_first_name,
        user.last_name AS whoDidIt_last_name,
        latitude AS location_latitude,
        longitude AS location_longitude
    FROM completed_survey
    LEFT JOIN user
        ON completed_survey.user_id=user.id
    LEFT JOIN interviewee 
        ON interviewee.id=completed_survey.interviewee_id
    LEFT JOIN survey_header
        ON survey_header.id=completed_survey.survey_header_id
    LEFT JOIN project
        ON project.id=survey_header.project_id
    GROUP BY interviewee_id, intervention_name;
    """,
    engine,
)

applied_interventions
# Out:
#                         executed_survey_id    intervention_name  \
# 0     f41b562c-9e92-4f09-9ad1-9986eac60173                 Ba?o
# 1     988da53a-74f3-4d3c-9cac-b0ee26f90702               Cocina
# 2     a2cfc2e2-b761-4056-b61b-b6f2c05858e0  Datos de la familia
# 3     d1592470-352f-4639-89a1-79ed95bf55b5               Filtro
# 4     90f6ab27-cdd2-4002-ada6-876de4bbd880                 Ba?o
# 5     15122c1b-ff36-4058-ae84-715b91e03c68               Cocina
# 6     262f3c4e-a616-4aa1-8bea-8c8db9572430  Datos de la familia
# 7     9dc8d3ab-675d-40c3-8aa7-df95fb5df750               Filtro
# 8     36333034-96ac-4a21-90ad-08716fdd84cb            Nutrici?n
# 9     3250a96a-342d-4691-9cb3-3787f170c2a0                 Tara
# 10    2b6e8dd3-1e04-4b21-a9d4-8352eb219d4f                 Ba?o
# 11    81ed52f8-bc0f-4fec-bb08-0e2b1ec6c6c6               Cocina
# 12    ebd92fe6-72f7-473e-9ce2-eb760ac97719  Datos de la familia
# 13    89e50e16-dbc9-4e5f-a823-1769a5f80bdc               Filtro
# 14    72584b73-81c5-451f-959d-669e6c12b746            Lavamanos
# 15    13bebd9b-d5c5-4116-ae2c-4eaa700c91cd            Nutrici?n
# 16    844a507f-563c-4a16-848f-89dda51c6cbb                 Tara
# 17    69a3e195-06ea-42bc-b0b7-20f8d3958f37                 Ba?o
# 18    081a9a4c-7a68-4047-9cbc-c55f944af740               Cocina
# 19    717004c2-d480-44d3-ab1c-6d548651c232  Datos de la familia
# 20    845ab286-3dd5-4045-b870-3cb0191a2dbb               Filtro
# 21    1a988e82-5112-408f-9cd5-8fe113b4d1c6            Nutrici?n
# 22    d45282fb-19a8-4811-9c15-7c509ed06410                 Tara
# 23    5fc9cab3-dd5e-4b4b-9787-3e0d84b2cc04                 Ba?o
# 24    93d52708-534d-42bd-b839-aecef34c6c23               Cocina
# 25    be35dff3-398b-4938-9def-0d715ce611a0  Datos de la familia
# 231   99da0c76-3636-41ad-8ddc-90dffde4c227            Lavamanos
# 232   55e4c25f-ef86-4282-a889-fbc23616607b            Nutrici?n
# 233   d8df4d90-7686-479b-a983-8c3f16ef2ac6                 Tara
# 234   7033bb73-f1f2-4f65-b062-852291af675c                 Ba?o
# 235   8a953091-ef9c-4c2b-b252-8278763bfc34               Cocina
# 236   f0fa6979-e538-4701-beba-be82cce92839  Datos de la familia
# 237   9754f625-ec90-4209-aa6d-acab253e939b               Filtro
# 238   196923cb-381c-47b0-b3b8-d4e4e3dc0e09            Lavamanos
# 239   18941f8d-1a9e-4457-aec4-0218264f32e8            Nutrici?n
# 240   11f5530d-3a22-46f9-aa43-a2d2cb667dbf                 Tara
# 241   158ee83b-2870-459f-9180-3e1039611545               Cocina
# 242   bd3ae751-a557-4611-b610-124ddf8e1a89  Datos de la familia
# 243   3266aec8-ff92-438d-883b-9294f31e12e9               Filtro
# 244   7b58b294-b44e-47a1-9f4e-7dc859c3a67d            Nutrici?n
# 245   10630af6-cb9c-4a12-9bc6-ea0e224b4393                 Tara
# 246   3436c219-aff4-45d9-9400-fc8539fc23a1               Cocina
# 247   030f2865-8e91-48ea-a621-079f342164e3  Datos de la familia
# 248   7d819b9b-7a8a-4967-b0a9-04b920669966               Filtro
# 249   4ce941db-a3a0-45d3-91ae-9c4514286cfe            Nutrici?n
# 250   7be75f21-15d3-4ef1-9c09-9f65b65dbe28                 Ba?o
# 251   6e3617ea-9c0f-40f3-8ef6-afec6f6e1d0d               Cocina
# 252   5c10b0e9-64d9-4a1e-b0a4-36bea42369f8  Datos de la familia
# 253   068eb479-5e98-4e79-99e4-fe940dd915fc               Filtro
# 254   89e4408c-da69-4635-a7c4-b6d5ceda187e            Lavamanos
# 255   75026734-c475-4214-813e-ce222cc10087            Nutrici?n
# 256   0f7b8077-3cb6-4e21-9e7d-3545d0524c24  Datos de la familia
# 257   743b9e3b-04a7-427d-a3bd-0b93d9e87efe                 Ba?o
# 258   63b5c407-6533-496e-8b70-74c38a7ce48a  Datos de la familia
# 259   8ba93d1d-900e-4b3e-be07-f868ebd46fb9               Filtro
# 260   030e5923-3661-4fde-ab7e-c62a036315f7            Nutrici?n
# 261   5e9b4abf-32a0-4902-bde4-e5d30ec8f12b               Cocina
# 262   a9d404a7-df1a-444b-84e6-cd190f4e5bf4  Datos de la familia
# 263   a6f0fdac-4037-448c-be1e-6e1b3f625ef7            Nutrici?n
# 264   31d65f9e-2346-45dd-b796-205e2cf5ff01                 Ba?o
# 265   7ebc32ac-feb9-4268-a71c-d275682bd5ac               Cocina
# 266   47c97e8a-696d-4394-a0b4-d5130c7ea68b  Datos de la familia
# 267   6f633fa6-f6cd-4ffb-8ba3-612f2ca28cac               Filtro
# 268   08e36f88-8f3c-476f-876b-40134f6b029d            Lavamanos
# 269   16f3905e-80b8-4e8a-b82e-520cca3da091            Nutrici?n
# 270   381f51b1-8b86-426f-b853-bcbdac549add                 Tara
# 271   13a89445-f430-48f3-b951-bda61632b699               Cocina
# 600   8c1eecae-a956-4520-87ab-308e17adea2c  Datos de la familia
# 601   0aba60a3-f67a-4fb4-bc40-32df8fdfd611               Filtro
# 602   7b0233a9-c7d7-4b0f-919f-b76738dce4cd            Nutrici?n
# 603   24288040-3890-479c-bf39-6b94fc98ff24                 Ba?o
# 604   a17f807f-f9ff-45ae-9d5e-b31733ee9fc5               Cocina
# 605   b1af8ac9-7917-4816-b7be-7f321b393b20  Datos de la familia
# 606   6a2bcad6-a6f1-4936-ba98-acc3cc989e88               Filtro
# 607   224b0dc9-16a3-42e2-80d6-87df3840ded0            Nutrici?n
# 608   9e5335aa-77da-437a-af5f-e57191d3b947               Cocina
# 609   ad205861-0bb1-4da9-a23e-371c29e4226d               Filtro
# 610   011db064-1944-4af6-b955-32c9ef80ff1c                 Ba?o
# 611   54eb101a-a39d-4510-848e-566770e2ddf7               Cocina
# 612   8c843341-af06-4ef8-b9b2-c9d9ea5f7b36  Datos de la familia
# 613   af797504-821e-47b9-84e5-b9e4c0afdaca               Filtro
# 614   450cd5bb-3a10-47de-9764-86be4c10136c            Lavamanos
# 615   d4ea9870-41d2-44bf-aef5-89acb93d60e7            Nutrici?n
# 616   20a433de-a804-48b3-bfca-5eb9c8014f1c                 Tara
# 617   37ffe20d-0c1c-4834-95e1-7e464caa6b8e                 Ba?o
# 618   3c5bc06a-aff7-4516-9368-e75a01923926               Cocina
# 619   5cdded64-78bc-42bf-912d-3d4ae58478db  Datos de la familia
# 620   46744d2f-81f9-4d04-9d2e-0f52b6366a79               Filtro
# 621   4e63359f-8544-4ddf-943a-169e88171838            Lavamanos
# 622   13c7b7d7-a638-44ba-a837-eb0f0b1b3805            Nutrici?n
# 623   5beac286-edaa-4d55-b871-c57b6fd28d35                 Ba?o
# 624   99aebdb0-9daf-4838-860c-697ea3eaebfb               Cocina
# 625   45d327f6-b5a6-4506-919c-9e1e1dc3aa45  Datos de la familia
# 626   0a709834-b1c4-4e8b-bff3-aa6953cc2532               Filtro
# 627   1ae82a9c-77ea-4a93-bdad-5a8bc6bc4ff1            Lavamanos
# 628   a65b7904-f142-4518-b075-f6218db89209            Nutrici?n
# 629   340915ac-0d7b-469f-bd45-e23a486795e6                 Tara
# 630   afd55bd1-0ce5-4381-9535-6f99110c8f2d                 Ba?o
# 631   1785a58d-b9b4-4178-aea6-3b628148ac37               Cocina
# 632   680bc0d5-69fe-45c2-ab15-b10e35f8fb3e  Datos de la familia
# 633   bc2ea9fa-c9d0-46d6-9cba-7f666116e68d               Filtro
# 634   21af43e0-2429-4632-ace7-d91d0c0cb4d0            Lavamanos
# 635   0ffdd4e9-4011-4157-94b2-0872a0b8b640            Nutrici?n
# 636   3841c99d-ea0b-43f7-9fdb-d6527563930d                 Tara
# 637   1114d013-f440-4a5c-bacd-c07ee50a61bb                 Ba?o
# 638   89182b04-6f29-4a42-88ee-2fa8f5a62aa7               Cocina
# 639   7a28abec-ad6c-4916-a515-df89b33ce059  Datos de la familia
# 640   50d5a0b7-3845-4354-8ac1-21d76309cbe6               Filtro
# 641   1f965ad8-a9e2-4592-b19b-d15d16c06b19            Nutrici?n
# 682   9602fd82-9ab6-40c7-8516-b4d4a698c3c7                 Ba?o
# 683   7f56c27e-27eb-47b6-bbeb-1948dfba802c               Cocina
# 684   953a8a3c-dd2c-446a-94e9-49cff4d82769  Datos de la familia
# 685   30a5d9b9-0d90-436e-bb8f-da77111eec4a               Filtro
# 686   75b3b40b-9878-43df-bae9-73e286f46a69            Nutrici?n
# 687   15b07aa6-6c44-456d-8022-024751725adb                 Tara
# 688   685b7864-815b-4267-87fb-ec4d335b3046                 Ba?o
# 689   1dcefba5-176f-4997-913d-ea216a1aa217               Cocina
# 690   ca85e8eb-09c8-4ea2-bc22-a7816b839008  Datos de la familia
# 691   4cb535d3-bb5a-41f9-a55e-e57d3392ba21               Filtro
# 692   6ac704a7-b075-4f23-b158-5ae1606e1171            Lavamanos
# 693   dea6db89-1ddf-499c-8e53-15fd89be9fd0            Nutrici?n
# 694   c9a8dc16-2df2-4dab-a74c-cd73c9141148                 Ba?o
# 695   523cc8b2-3f51-425d-a4f4-cb5a634af5c5                 Ba?o
# 696   487933ab-d3bb-4c34-b6ad-40eb34b4ec31               Cocina
# 697   b81ea188-8b4f-45e0-a37f-9908e6ba138f  Datos de la familia
# 698   46d3e1ce-6094-4859-a798-84521125b51b               Filtro
# 699   56ac7169-8c6e-457f-b223-16ad6b2afd19            Nutrici?n
# 700   1d7a9d87-c74a-44a6-af9f-1a0c1b4e53ff                 Ba?o
# 701   492fa7b8-940b-494d-930e-ca573b4aec47               Cocina
# 702   47c48a72-f901-45ef-9e4c-f4df4032f6c7  Datos de la familia
# 703   4423fbb3-4d8f-4635-bec3-0b7ce4ebe46f               Filtro
# 704   58f93c28-6e64-4322-9443-66a76d5319f4            Lavamanos
# 705   c35d1d8b-80cb-44fa-a2a7-85d59cea1be5            Nutrici?n
# 706   64dcd0f1-6b47-49fb-85f4-97143ead40e1                 Tara
# 707   d3856e75-0781-40df-9531-b408ee17558f                 Ba?o
# 708   5ef6adb4-4082-48ee-906e-f0b61cbddaa2               Cocina
# 709   8561276e-9498-4913-9777-28cea185f73b  Datos de la familia
# 710   6925c241-be19-4818-9585-5de17bb03865               Filtro
# 711   27195ca2-04b6-47f5-9a4d-c815af954034            Nutrici?n
# 712   033e51bc-4488-44a9-9dd3-4d74ac0e933c                 Tara
# 713   471d0c79-d207-4a2d-abab-12e15c559d7a                 Ba?o
# 714   b1d3a057-6b1d-41e4-b804-8316e3cfaa7c               Cocina
# ...
# 1121               auca                NaN                 NaN
# 1122         Sarawaylla                NaN                 NaN
# 1123         Sarawaylla                NaN                 NaN
# 1124         Sarawaylla                NaN                 NaN
# 1125         Sarawaylla                NaN                 NaN
# 1126         Sarawaylla                NaN                 NaN
# 1127         Sarawaylla                NaN                 NaN
# 1128         Sarawaylla                NaN                 NaN
# 1129             yapura                NaN                 NaN
# 1130             yapura                NaN                 NaN
# 1131             yapura                NaN                 NaN
# 1132             yapura                NaN                 NaN
# 1133             yapura                NaN                 NaN
# 1134             yapura                NaN                 NaN
# 1135             yapura                NaN                 NaN
# 1136             yapura                NaN                 NaN
# 1220             yapura                NaN                 NaN
# 1221             yapura                NaN                 NaN
# 1222             yapura                NaN                 NaN
# 1223             yapura                NaN                 NaN
# 1224             yapura                NaN                 NaN
# 1225             yapura                NaN                 NaN
# 1226             yapura                NaN                 NaN
# 1227             yapura                NaN                 NaN
# 1228       Choque Ojeda                NaN                 NaN
# 1229       Choque Ojeda                NaN                 NaN
# 1230       Choque Ojeda                NaN                 NaN
# 1231       Choque Ojeda                NaN                 NaN
# 1232       Choque Ojeda                NaN                 NaN
# 1233       Choque Ojeda                NaN                 NaN
# 1234               bbmm                NaN                 NaN
# 1235               bbmm                NaN                 NaN
# 1236               bbmm                NaN                 NaN
# 1237               bbmm                NaN                 NaN
# 1238               bbmm                NaN                 NaN
# 1239               bbmm                NaN                 NaN
# 1240               bbmm                NaN                 NaN
# 1241       Choque Ojeda                NaN                 NaN
# 1242       Choque Ojeda                NaN                 NaN
# 1243       Choque Ojeda                NaN                 NaN
# 1244       Choque Ojeda                NaN                 NaN
# 1245       Choque Ojeda                NaN                 NaN
# 1246       Choque Ojeda                NaN                 NaN
# 1247       Choque Ojeda                NaN                 NaN
# 1248             flores                NaN                 NaN
# 1249             flores                NaN                 NaN
# 1250             flores                NaN                 NaN
# 1251             flores                NaN                 NaN
# 1252             flores                NaN                 NaN
# 1253             flores                NaN                 NaN
# 1254             flores                NaN                 NaN
# 1255      Yapura Colque                NaN                 NaN
# 1256      Yapura Colque                NaN                 NaN
# 1257      Yapura Colque                NaN                 NaN
# 1258      Yapura Colque                NaN                 NaN
# 1259      Yapura Colque                NaN                 NaN
# 1260    Co?aca Calizaya         -18.368010          -65.834328
# 1261    Co?aca Calizaya         -18.368010          -65.834328
# 1262    Co?aca Calizaya         -18.368010          -65.834328
# 1263    Co?aca Calizaya         -18.368010          -65.834328
# 1264    Co?aca Calizaya         -18.368010          -65.834328
# 1265             yapura                NaN                 NaN
# 1266             yapura                NaN                 NaN
# 1267             yapura                NaN                 NaN
# 1268             yapura                NaN                 NaN
# 1269             yapura                NaN                 NaN
# 1270         Sarawaylla                NaN                 NaN
# 1271         Sarawaylla                NaN                 NaN
# 1272         Sarawaylla                NaN                 NaN
# 1273         Sarawaylla                NaN                 NaN
# 1274         Sarawaylla                NaN                 NaN
# 1275         Sarawaylla                NaN                 NaN
# 1276         Sarawaylla                NaN                 NaN
# 1277       Choque Ojeda                NaN                 NaN
# 1278       Choque Ojeda                NaN                 NaN
# 1279       Choque Ojeda                NaN                 NaN
# 1280       Choque Ojeda                NaN                 NaN
# 1281       Choque Ojeda                NaN                 NaN
# 1282       Choque Ojeda                NaN                 NaN
# 1283             flores                NaN                 NaN
# 1284             flores                NaN                 NaN
# 1285             flores                NaN                 NaN
# 1286             flores                NaN                 NaN
# 1287             flores                NaN                 NaN
# 1288             flores                NaN                 NaN
# 1289       Choque Ojeda                NaN                 NaN
# 1290       Choque Ojeda                NaN                 NaN
# 1291       Choque Ojeda                NaN                 NaN
# 1292       Choque Ojeda                NaN                 NaN
# 1293       Choque Ojeda                NaN                 NaN
# 1294       Choque Ojeda                NaN                 NaN
# 1295       Choque Ojeda                NaN                 NaN
# 1296         Sarawaylla                NaN                 NaN
# 1297         Sarawaylla                NaN                 NaN
# 1298         Sarawaylla                NaN                 NaN
# 1299         Sarawaylla                NaN                 NaN
# 1300         Sarawaylla                NaN                 NaN
# 1301         Sarawaylla                NaN                 NaN
# 1302         Sarawaylla                NaN                 NaN
# 1303               auca                NaN                 NaN
# 1304               auca                NaN                 NaN
# 1305               auca                NaN                 NaN
# 1306             flores                NaN                 NaN
# 1307             flores                NaN                 NaN
# 1308             flores                NaN                 NaN
# 1309             flores                NaN                 NaN
# 1310             flores                NaN                 NaN
# 1311             flores                NaN                 NaN
# 1312             flores                NaN                 NaN
# 1313             mamani                NaN                 NaN
# 1314             mamani                NaN                 NaN
# 1315             mamani                NaN                 NaN
# 1316             mamani                NaN                 NaN
# 1317             mamani                NaN                 NaN
# 1318             mamani                NaN                 NaN
# 1319             mamani                NaN                 NaN
# 1320      Aguilar Palla                NaN                 NaN
# 1321      Aguilar Palla                NaN                 NaN
# 1322      Aguilar Palla                NaN                 NaN
# 1323      Aguilar Palla                NaN                 NaN
# 1324      Aguilar Palla                NaN                 NaN
# 1325      Aguilar Palla                NaN                 NaN
# 1326      Aguilar Palla                NaN                 NaN
# 1327         Sarawaylla                NaN                 NaN
# 1328         Sarawaylla                NaN                 NaN
# 1329         Sarawaylla                NaN                 NaN
# 1330         Sarawaylla                NaN                 NaN
# 1331         Sarawaylla                NaN                 NaN
# 1332         Sarawaylla                NaN                 NaN
# 1333         Sarawaylla                NaN                 NaN
# 1334             mamani                NaN                 NaN
# 1335             mamani                NaN                 NaN
# 1336             mamani                NaN                 NaN
# 1337             mamani                NaN                 NaN
# 1338             mamani                NaN                 NaN
# 1339             mamani                NaN                 NaN
# 1340             mamani                NaN                 NaN
# 1341           baltazar                NaN                 NaN
# 1342           baltazar                NaN                 NaN
# 1343           baltazar                NaN                 NaN
# 1344         Sarawaylla                NaN                 NaN
# 1345         Sarawaylla                NaN                 NaN
# 1346         Sarawaylla                NaN                 NaN
# 1347         Sarawaylla                NaN                 NaN
# 1348         Sarawaylla                NaN                 NaN
# 1349         Sarawaylla                NaN                 NaN
# 1350       Choque Ojeda                NaN                 NaN
# 1351       Choque Ojeda                NaN                 NaN
# 1352       Choque Ojeda                NaN                 NaN
# 1353       Choque Ojeda                NaN                 NaN
# 1354       Choque Ojeda                NaN                 NaN
# 1355       Choque Ojeda                NaN                 NaN
# 1356       Choque Ojeda                NaN                 NaN
# 1357                aro                NaN                 NaN
# 1358           baltazar                NaN                 NaN
# 1359           baltazar                NaN                 NaN
# 1360               bbmm                NaN                 NaN
# 1361               bbmm                NaN                 NaN
# 1362               bbmm                NaN                 NaN
# 1363               bbmm                NaN                 NaN
# 1364               bbmm                NaN                 NaN
# 1365               bbmm                NaN                 NaN
# 1366               bbmm                NaN                 NaN

# %%
# applied intervention is uniquely defined based on interviewed person (project_id/interviewee_id) and intervention beneficiary (interviewee_id)
intervention_id = 9
interviewee_id = "079397b5-9f2e-4490-9ebf-795ff2c8c679"

surveys_for_intervention_id = interventions = pandas.read_sql(f""" 
    SELECT * 
    FROM completed_survey
    LEFT JOIN survey_header
        ON survey_header.id=completed_survey.survey_header_id
    WHERE project_id="{intervention_id}"
    AND interviewee_id="{interviewee_id}"
    ;
    """,
    engine,
)

# WHERE completed_survey.id = {SURVEY_ID}
surveys_for_intervention_id

# %% [markdown]
# ### List of all questions and corresponding answers

# %%
select = """
        question.id AS question_id,
        question_name,
        option_choice_name,
        answer_text,
        dependent_question_option_id,
        dependent_question_id,
        question_images_id,
        input_type_name
        """
# select = "*"

question_answers = pandas.read_sql(f""" 
    SELECT {select}
    FROM answer
    LEFT JOIN question
        ON answer.question_id=question.id
    LEFT JOIN question_option
        ON answer.question_option_id=question_option.id
    LEFT JOIN option_choice
        ON question_option.option_choice_id=option_choice.id
    LEFT JOIN input_type
        ON question.input_type_id=input_type.id
    ;
    """,
    engine,
)

question_answers

# %% [markdown]
# ## Get questions for a given survey
#
# chain of dependent questions linked to one question better solved in application code:
#
# (1) run query questions_for_survey_id,
#
# (2) when creating objects to be written to Amplify, link array of question_options based on result of subsequent query questions_for_question_id
#
# (3) recursively get chain of follow-up question by running query follow_up_question_by_question_id

# %%
unique_survey_ids = pandas.read_sql(f""" 
    SELECT DISTINCT
        id
    FROM survey_header;
    """,
    engine,
).values.tolist()
unique_survey_ids = [unique_survey_ids[i][0] for i in range(len(unique_survey_ids))]
print(f"Unique survey ids are: {unique_survey_ids}")

SURVEY_ID = unique_survey_ids[0]
print(f"Querying all survey data for survey id: {SURVEY_ID}.")


select = """
        question.id AS question_id,
        question_name,
        dependent_question_id,
        dependent_question_option_id,
        dependent_question_option_id,
        dependent_question_id,
        question_images_id,
        input_type_name,
        url AS question_image_url
        """
# select = "*"

questions_for_survey_id = pandas.read_sql(f""" 
    SELECT 
        {select}
    FROM question
    LEFT JOIN survey_section
        ON survey_section.id=question.survey_section_id
    LEFT JOIN survey_header
        ON survey_header.id=survey_section.survey_header_id
    LEFT JOIN question_image
        ON question_image.id=question.question_images_id
    LEFT JOIN input_type
        ON input_type.id=question.input_type_id
    WHERE survey_header.id = {SURVEY_ID};
    """,
    engine,
)

questions_for_survey_id

# %%
select = """
    option_choice_name
"""

select = "*"

QUESTION_ID = 3763

questions_for_question_id = pandas.read_sql(f""" 
    SELECT 
        {select}
    FROM question_option
    LEFT JOIN option_choice
        ON question_option.option_choice_id=option_choice.id
    WHERE question_id={QUESTION_ID}
    ;
    """,
    engine,
)

questions_for_question_id

# %%
DEPENDENT_QUESTION_ID = 3792

follow_up_question_by_question_id = pandas.read_sql(f""" 
    SELECT 
        {select}
    FROM question
    LEFT JOIN survey_section
        ON survey_section.id=question.survey_section_id
    LEFT JOIN survey_header
        ON survey_header.id=survey_section.survey_header_id
    LEFT JOIN question_image
        ON question_image.id=question.question_images_id
    LEFT JOIN input_type
        ON input_type.id=question.input_type_id
    WHERE question.id = {DEPENDENT_QUESTION_ID};
    """,
    engine,
)

follow_up_question_by_question_id
